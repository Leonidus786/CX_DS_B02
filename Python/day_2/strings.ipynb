# %% [markdown]
# # strings == set of characters like "name".

# %%
a = "ronak"

# %%
a.upper()
# Out:
# 'RONAK'

# %%
a.lower()
# Out:
# 'ronak'

# %%
a = 10

# %%
type(a)
# Out:
# int

# %%
b = float(a)

# %%
b
# Out:
# 10.0

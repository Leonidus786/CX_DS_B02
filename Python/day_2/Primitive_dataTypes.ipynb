# %% [markdown]
# # Primitive Data Types=== int(),float(),str(),bool()

# %%
# integer 

a = 10

# %%
type(a)
# Out:
# int

# %%
#  float

b = 6.7

# %%
print(type(b))
# Out:
# <class 'float'>

# %%
c = 'cat'

# %%
print(type(c))
# Out:
# <class 'str'>

# %%
5 < 7
# Out:
# True

# %%
d = True

# %%
print(type(d))
# Out:
# <class 'bool'>

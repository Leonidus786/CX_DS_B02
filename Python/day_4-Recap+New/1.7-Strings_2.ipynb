# %%
Name = "Abhishek"

Age = 30

type(Age)
# Out:
# int

# %%
msg = "My name is "+ Name+ " and my age is "+ str(Age)
print(msg)


# msg_1 = 'Good Noon My name is '+Name + " and my age is "+ Age
# Out:
# My name is Abhishek and my age is 30

# %%
Maths = 85
English = 75
Social_Science = 78
Science = 79
Sanskrit = 80
Hindi = 79

# %%
Report = "Hi guys my marks in Maths are "+ str(Maths)+ " in English it is " +str(English) + " in Social Science it is "+str(Social_Science)+ " in Science it is "+str(Science)


Report
# Out:
# 'Hi guys my marks in Maths are 85 in English it is 75 in Social Science it is 78 in Science it is 79'

# %% [markdown]
# ### f- strings == f"{Placeholder}or{Modifiers} what can you keep is {Var_name} "
#
# -- f-strings is used for formatting strings.

# %%
Report = f"Hi guys my marks in maths is {Maths + 5}, and in english it is {English}, also I got {Science} in Science."

# %%
Report
# Out:
# 'Hi guys my marks in maths is 90, and in english it is 75, also I got 79 in Science.'

# %%
mag = f"My name is {Name} and my age is {Age}."

# %%
mag
# Out:
# 'My name is Abhishek and my age is 30.'

# %%
old_price = 59
txt = f"The new price is {old_price + 5} dollars."
print(txt)
# Out:
# The new price is 64 dollars.

# %%
# 59.00
price = 59
txt = f"The price is {price:.2f} dollars"
print(txt)
# Out:
# The price is 59.00 dollars

# %%
msg = "I am an "AI" Engineer"
msg

# %%
# Way - 1
msg = "I am a \"AI\" enginner"
print(msg)

# %%
# Way -2

msg = 'I am a "AI" enginner'
msg

# %%
msg = "I am a 'AI' enginner"
msg

# %%
# \n -- New line character
txt = "Hello\nWorld!\n I am here to learn python"
print(txt)
# Out:
# Hello
# World!
#  I am here to learn python

# %%
msg = "I am Abhishek\nI am an AI developer"

print(msg)
# Out:
# I am Abhishek
# I am an AI developer

# %%
msg = "I am Abhishek\nI am an AI Developer."
print(msg)

# %%
a = "abhishek"

print(a)
# Out:
# abhishek

# %%
print(a.capitalize())
# Out:
# Abhishek

# %%
b = "Hello, World!"
print(b[:5])

# %%
a

# %%
d_1 = a.upper()
d_1

# %%
d_1.lower()

# %%
saying = "      Yashi             Chauhan                  "


saying
# Out:
# '      Yashi             Chauhan                  '

# %%
saying.strip()
# Out:
# 'Yashi             Chauhan'

# %%
a = "Hello, World!"
print(a.replace("H", "J"))
# Out:
# Jello, World!

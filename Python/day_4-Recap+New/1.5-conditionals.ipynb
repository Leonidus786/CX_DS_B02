# %% [markdown]
# # Flowchart == Graphical Representation of code or a process

# %%
a = input("Enter a number")
type(a)
# Out:
# str

# %%
b = 10
print(b)
# Out:
# 10

# %%
if b == 5:
    print("ye chalna chahiye")

# %%
a = 2

if a == 2:
    print("This is good")
# Out:
# This is good

# %%
a = int(input("Please enter a number.: "))

if a >= 10:
    print("a is greater")
else:
    print("do nothing")
# Out:
# do nothing

# %%
a = 0

# %%
if a ==1:
    print("do this")
elif a == 2:
    print("ab m v chalunga")
    print(a + 5)
elif a > 2:
    print("Mai v chl skta hu")
else:
    print("Bhaukaal h iska")
# Out:
# Bhaukaal h iska

# %%
import keyword

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
age = int(input("Enter your age: "))

if age < 18:
    print("Wait till you turn 18")
elif age >= 18 and age < 55:
    print("You can apply and schedule a test date.")
elif age >= 55:
    print("Bhai tmhara to nhi bnega")
# Out:
# Bhai tmhara to nhi bnega

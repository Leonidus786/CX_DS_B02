# %%
a = "Abhishek"

# %%
print(a)
# Out:
# Abhishek

# %%
type(a)
# Out:
# str

# %%
a
# Out:
# 'Abhishek'

# %%
len(a)
# Out:
# 8

# %%
# slicing var_name[start : Ending : Escape]
a[:4]
# Out:
# 'Abhi'

# %%
a[4:]
# Out:
# 'shek'

# %%
a[::2]
# Out:
# 'Ahse'

# %%
a.upper()
# Out:
# 'ABHISHEK'

# %%
a.lower()
# Out:
# 'abhishek'

# %%
a.replace('b','a')
# Out:
# 'Aahishek'

# %%
# Concatenation == when combining two or more strings together.

b = "Upadhayay"

# %%
a
# Out:
# 'Abhishek'

# %%
c = a +' '+ b

# %%
c
# Out:
# 'Abhishek Upadhayay'

# %%
txt = "We are the so-called "Vikings" from the north."
# Out:
#   Cell In[19], line 1
#     txt = "We are the so-called "Vikings" from the north."
#                                  ^
# SyntaxError: invalid syntax

# %%
txt = 'We are the so-called "Vikings" from the north.'

# %%
txt = "We are the so-called \"Vikings\" from the north."

# %%
txt
# Out:
# 'We are the so-called "Vikings" from the north.'
